# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("44a688d7-8cd5-4c31-baa5-ec9fee468092.csv")
df
# Out:
#      IndicatorCode                                          Indicator  \
# 0          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 1          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 2          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 3          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# ...            ...                                                ...
# 9445       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9446       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9447       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9448       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9449       SDGPM25  Concentrations of fine particulate matter (PM2.5)
#
#      ValueType ParentLocationCode         ParentLocation Location type  \
# ...

# %% [markdown]
# # PREPARAÇÃO DE DADOS

# %% [markdown]
# ### DADOS NULOS

# %%
df.isnull().any()
# Out:
# IndicatorCode                 False
# Indicator                     False
# ValueType                     False
# ParentLocationCode            False
# ParentLocation                False
# Location type                 False
# SpatialDimValueCode           False
# Location                      False
# Period type                   False
# Period                        False
# IsLatestYear                  False
# Dim1 type                     False
# Dim1                          False
# Dim1ValueCode                 False
# Dim2 type                      True
# Dim2                           True
# Dim2ValueCode                  True
# Dim3 type                      True
# Dim3                           True
# Dim3ValueCode                  True
# DataSourceDimValueCode         True
# DataSource                     True
# FactValueNumericPrefix         True
# FactValueNumeric              False
# FactValueUoM                   True
# FactValueNumericLowPrefix      True
# ...

# %%
df[df.isnull().T.any()]
# Out:
#      IndicatorCode                                          Indicator  \
# 0          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 1          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 2          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 3          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# ...            ...                                                ...
# 9445       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9446       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9447       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9448       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9449       SDGPM25  Concentrations of fine particulate matter (PM2.5)
#
#      ValueType ParentLocationCode         ParentLocation Location type  \
# ...

# %%
df.isnull().sum()
# Out:
# IndicatorCode                    0
# Indicator                        0
# ValueType                        0
# ParentLocationCode               0
# ParentLocation                   0
# Location type                    0
# SpatialDimValueCode              0
# Location                         0
# Period type                      0
# Period                           0
# IsLatestYear                     0
# Dim1 type                        0
# Dim1                             0
# Dim1ValueCode                    0
# Dim2 type                     9450
# Dim2                          9450
# Dim2ValueCode                 9450
# Dim3 type                     9450
# Dim3                          9450
# Dim3ValueCode                 9450
# DataSourceDimValueCode        9450
# DataSource                    9450
# FactValueNumericPrefix        9450
# FactValueNumeric                 0
# FactValueUoM                  9450
# FactValueNumericLowPrefix     9450
# FactValueNumericLow              0
# ...

# %%
df.dropna(axis=1, how='all', inplace=True)
df
# Out:
#      IndicatorCode                                          Indicator  \
# 0          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 1          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 2          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 3          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# ...            ...                                                ...
# 9445       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9446       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9447       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9448       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 9449       SDGPM25  Concentrations of fine particulate matter (PM2.5)
#
#      ValueType ParentLocationCode         ParentLocation Location type  \
# ...

# %%
df.isnull().sum()
# Out:
# IndicatorCode           0
# Indicator               0
# ValueType               0
# ParentLocationCode      0
# ParentLocation          0
# Location type           0
# SpatialDimValueCode     0
# Location                0
# Period type             0
# Period                  0
# IsLatestYear            0
# Dim1 type               0
# Dim1                    0
# Dim1ValueCode           0
# FactValueNumeric        0
# FactValueNumericLow     0
# FactValueNumericHigh    0
# Value                   0
# Language                0
# DateModified            0
# dtype: int64

# %% [markdown]
# ### OUTLIERS

# %%
df.boxplot(column=['FactValueNumeric'])
# Out:
# <Axes: >

# %%
df.FactValueNumeric.min()
# Out:
# 4.59

# %%
df.FactValueNumeric.max()
# Out:
# 97.49

# %%
y = df['FactValueNumeric'].values
x = df['FactValueNumeric'].index
plt.scatter(x,y)
plt.show()

# %%
df['FactValueNumeric'].values
# Out:
# array([10.01, 10.02, 10.06, ...,  9.94,  9.95, 92.79])

# %% [markdown]
# # ANÁLISE

# %%
#df_ordenado[df_ordenado['Period']==2019].Value
#pm2,5 total do Brasil por ano
import matplotlib.pyplot as plt

x = df[(df['Dim1']=='Total') & (df['Location']=='Brazil')]['Period']
y = df[(df['Dim1']=='Total') & (df['Location']=='Brazil')]['FactValueNumeric']
plt.bar(x,y)
plt.show()

# %%
#df_ordenado[df_ordenado['Period']==2019].Value
#pm2,5 total do Brasil por ano
import matplotlib.pyplot as plt

x = df[(df['Dim1']=='Total') & (df['Location']=='Brazil')]['Period']
y_total = df[(df['Dim1']=='Total') & (df['Location']=='Brazil')]['FactValueNumeric']
y_rural = df[(df['Dim1']=='Rural') & (df['Location']=='Brazil')]['FactValueNumeric']
y_cities = df[(df['Dim1']=='Cities') & (df['Location']=='Brazil')]['FactValueNumeric']
y_towns = df[(df['Dim1']=='Towns') & (df['Location']=='Brazil')]['FactValueNumeric']
y_urban = df[(df['Dim1']=='Urban') & (df['Location']=='Brazil')]['FactValueNumeric']
plt.plot(x,y_total, label="Total")
plt.plot(x,y_rural, label="Rural")
plt.plot(x,y_cities, label="Cities")
plt.plot(x,y_towns, label="Towns")
plt.plot(x,y_urban, label="Urban")
plt.legend()
plt.ylabel('Média de PM2.5 µg/m³')
plt.show()

# %%
df.groupby('Dim1')['Dim1'].count()
# Out:
# Dim1
# Cities    1740
# Rural     1930
# Total     1950
# Towns     1900
# Urban     1930
# Name: Dim1, dtype: int64

# %%
# Agrupando por país e calcular a média dos valores de PM2.5
x = df[df.Dim1 == 'Total'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=False).head(5).index
y = df[df.Dim1 == 'Total'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=False).head(5).values

media_brazil = df[(df['Dim1']=='Total') & (df['Location']=='Brazil')]['FactValueNumeric'].mean()

y_brazil = []

for valor in range(5):
    y_brazil.append(media_brazil)



# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(x,y, color='skyblue', label ='Países')
plt.plot(x,y_brazil, color='brown', label='Brasil')
plt.xlabel('Países')
plt.ylabel('Média de PM2.5 µg/m³')
plt.title('Top 5 Países com Maiores Índices de PM2.5')
plt.legend()
plt.show()

# %%
# Agrupando por país e calcular a média dos valores de PM2.5
x = df[df.Dim1 == 'Total'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=True).head(5).index
y = df[df.Dim1 == 'Total'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=True).head(5).values

media_brazil = df[(df['Dim1']=='Total') & (df['Location']=='Brazil')]['FactValueNumeric'].mean()

y_brazil = []

for valor in range(5):
    y_brazil.append(media_brazil)

# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(x,y, color='skyblue', label ='Países')
plt.plot(x,y_brazil, color='brown', label='Brasil')
plt.xlabel('Países')
plt.ylabel('Média de PM2.5 µg/m³')
plt.title('Top 5 Países com menores Índices de PM2.5')
plt.legend()
plt.show()

# %%
# Agrupando por país e calcular a média dos valores de PM2.5
x = df[df.Dim1 == 'Cities'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=False).head(5).index
y = df[df.Dim1 == 'Cities'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=False).head(5).values

media_brazil = df[(df['Dim1']=='Cities') & (df['Location']=='Brazil')]['FactValueNumeric'].mean()

y_brazil = []

for valor in range(5):
    y_brazil.append(media_brazil)
    
# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(x,y, color='skyblue', label ='Países')
plt.plot(x,y_brazil, color='brown', label='Brasil')
plt.xlabel('Países')
plt.ylabel('Média de PM2.5 µg/m³')
plt.title('Gráfico com os cinco países com maiores índices de PM2,5 em cidades grandes')
plt.legend()
plt.show()

# %%
# Agrupando por país e calcular a média dos valores de PM2.5
x = df[df.Dim1 == 'Cities'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=True).head(5).index
y = df[df.Dim1 == 'Cities'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=True).head(5).values

media_brazil = df[(df['Dim1']=='Cities') & (df['Location']=='Brazil')]['FactValueNumeric'].mean()

y_brazil = []

for valor in range(5):
    y_brazil.append(media_brazil)
    
# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(x,y, color='skyblue', label ='Países')
plt.plot(x,y_brazil, color='brown', label='Brasil')
plt.xlabel('Países')
plt.ylabel('Média de PM2.5 µg/m³')
plt.title('Gráfico com os cinco países com menores índices de PM2,5 em cidades grandes')
plt.legend()
plt.show()

# %%
# Agrupando por país e calcular a média dos valores de PM2.5
x = df[df.Dim1 == 'Rural'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=False).head(5).index
y = df[df.Dim1 == 'Rural'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=False).head(5).values

media_brazil = df[(df['Dim1']=='Rural') & (df['Location']=='Brazil')]['FactValueNumeric'].mean()

y_brazil = []

for valor in range(5):
    y_brazil.append(media_brazil)
    
# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(x,y, color='skyblue', label ='Países')
plt.plot(x,y_brazil, color='brown', label='Brasil')
plt.xlabel('Países')
plt.ylabel('Média de PM2.5 µg/m³')
plt.title('Gráfico com os cinco países com maiores índices de PM2,5 nas regiões rurais')
plt.legend()
plt.show()

# %%
# Agrupando por país e calcular a média dos valores de PM2.5
x = df[df.Dim1 == 'Rural'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=True).head(5).index
y = df[df.Dim1 == 'Rural'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=True).head(5).values

media_brazil = df[(df['Dim1']=='Rural') & (df['Location']=='Brazil')]['FactValueNumeric'].mean()

y_brazil = []

for valor in range(5):
    y_brazil.append(media_brazil)
    
# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(x,y, color='skyblue', label ='Países')
plt.plot(x,y_brazil, color='brown', label='Brasil')
plt.xlabel('Países')
plt.ylabel('Média de PM2.5 µg/m³')
plt.title('Gráfico com os cinco países com menores índices de PM2,5 nas regiões rurais')
plt.legend()
plt.show()

# %%
# Agrupando por país e calcular a média dos valores de PM2.5
x = df[df.Dim1 == 'Towns'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=False).head(5).index
y = df[df.Dim1 == 'Towns'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=False).head(5).values

media_brazil = df[(df['Dim1']=='Towns') & (df['Location']=='Brazil')]['FactValueNumeric'].mean()

y_brazil = []

for valor in range(5):
    y_brazil.append(media_brazil)
    
# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(x,y, color='skyblue', label ='Países')
plt.plot(x,y_brazil, color='brown', label='Brasil')
plt.xlabel('Países')
plt.ylabel('Média de PM2.5 µg/m³')
plt.title('Gráfico com os cinco países com maiores índices de PM2,5 nas cidades pequenas')
plt.legend()
plt.show()

# %%
# Agrupando por país e calcular a média dos valores de PM2.5
x = df[df.Dim1 == 'Towns'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=True).head(5).index
y = df[df.Dim1 == 'Towns'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=True).head(5).values

media_brazil = df[(df['Dim1']=='Towns') & (df['Location']=='Brazil')]['FactValueNumeric'].mean()

y_brazil = []

for valor in range(5):
    y_brazil.append(media_brazil)

# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(x,y, color='skyblue', label ='Países')
plt.plot(x,y_brazil, color='brown', label='Brasil')
plt.xlabel('Países')
plt.ylabel('Média de PM2.5 µg/m³')
plt.title('Gráfico com os cinco países com menores índices de PM2,5 nas cidades pequenas')
plt.legend()
plt.show()

# %%
# Agrupando por país e calcular a média dos valores de PM2.5
x = df[df.Dim1 == 'Urban'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=False).head(5).index
y = df[df.Dim1 == 'Urban'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=False).head(5).values

media_brazil = df[(df['Dim1']=='Urban') & (df['Location']=='Brazil')]['FactValueNumeric'].mean()

y_brazil = []

for valor in range(5):
    y_brazil.append(media_brazil)
    
# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(x,y, color='skyblue', label ='Países')
plt.plot(x,y_brazil, color='brown', label='Brasil')
plt.xlabel('Países')
plt.ylabel('Média de PM2.5 µg/m³')
plt.title('Gráfico com os cinco países com maiores índices de PM2,5 nas regiões urbanas')
plt.legend()
plt.show()

# %%
# Agrupando por país e calcular a média dos valores de PM2.5
x = df[df.Dim1 == 'Urban'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=True).head(5).index
y = df[df.Dim1 == 'Urban'].groupby('Location')['FactValueNumeric'].mean().sort_values(ascending=True).head(5).values

media_brazil = df[(df['Dim1']=='Urban') & (df['Location']=='Brazil')]['FactValueNumeric'].mean()

y_brazil = []

for valor in range(5):
    y_brazil.append(media_brazil)

# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(x,y, color='skyblue', label ='Países')
plt.plot(x,y_brazil, color='brown', label='Brasil')
plt.xlabel('Países')
plt.ylabel('Média de PM2.5 µg/m³')
plt.title('Gráfico com os cinco países com menores índices de PM2,5 nas regiões urbanas')
plt.legend()
plt.show()

# %%
df_brazil = df[(df['Location'] == 'Brazil') & (df.Dim1 == 'Total')]
x = df_brazil.Period
y = df_brazil.FactValueNumeric

plt.plot(x,y)
plt.title('PM2.5 ao longo do tempo no Brasil')
plt.xlabel('Anos')
plt.ylabel('PM2.5 µg/m³')
plt.show()

# %%
df_brazil.FactValueNumeric.mean()
# Out:
# 13.107

# %%
df_brazil.FactValueNumeric.min()
# Out:
# 10.94

# %%
df_brazil.FactValueNumeric.max()
# Out:
# 14.89

# %%
#Média Total de todos os países
df[df.Dim1 == 'Total'].FactValueNumeric.mean()
# Out:
# 22.667046153846155

# %%
# Desvio Padrão
df[df.Dim1 == 'Total'].FactValueNumeric.std()
# Out:
# 14.406437315097222

# %% [markdown]
# # Ranking do Brasil ao longo dos anos de 2010 a 2019 em relação ao poluente PM2.5

# %%
df_2010 = df[(df['Dim1']=='Total') & (df['Period']==2010)].sort_values(by=['FactValueNumeric'])
df_2010 = df_2010.reset_index()
df_2010[df_2010['Location']=='Brazil'].index + 1
# Out:
# Index([67], dtype='int64')

# %%
df_2011 = df[(df['Dim1']=='Total') & (df['Period']==2011)].sort_values(by=['FactValueNumeric'])
df_2011 = df_2011.reset_index()
df_2011[df_2011['Location']=='Brazil'].index + 1
# Out:
# Index([68], dtype='int64')

# %%
df_2012 = df[(df['Dim1']=='Total') & (df['Period']==2012)].sort_values(by=['FactValueNumeric'])
df_2012 = df_2012.reset_index()
df_2012[df_2012['Location']=='Brazil'].index + 1
# Out:
# Index([65], dtype='int64')

# %%
df_2013 = df[(df['Dim1']=='Total') & (df['Period']==2013)].sort_values(by=['FactValueNumeric'])
df_2013 = df_2013.reset_index()
df_2013[df_2013['Location']=='Brazil'].index + 1
# Out:
# Index([59], dtype='int64')

# %%
df_2014 = df[(df['Dim1']=='Total') & (df['Period']==2014)].sort_values(by=['FactValueNumeric'])
df_2014 = df_2014.reset_index()
df_2014[df_2014['Location']=='Brazil'].index + 1
# Out:
# Index([64], dtype='int64')

# %%
df_2015 = df[(df['Dim1']=='Total') & (df['Period']==2015)].sort_values(by=['FactValueNumeric'])
df_2015 = df_2015.reset_index()
df_2015[df_2015['Location']=='Brazil'].index + 1
# Out:
# Index([53], dtype='int64')

# %%
df_2016 = df[(df['Dim1']=='Total') & (df['Period']==2016)].sort_values(by=['FactValueNumeric'])
df_2016 = df_2016.reset_index()
df_2016[df_2016['Location']=='Brazil'].index + 1
# Out:
# Index([56], dtype='int64')

# %%
df_2017 = df[(df['Dim1']=='Total') & (df['Period']==2017)].sort_values(by=['FactValueNumeric'])
df_2017 = df_2017.reset_index()
df_2017[df_2017['Location']=='Brazil'].index + 1
# Out:
# Index([78], dtype='int64')

# %%
df_2018 = df[(df['Dim1']=='Total') & (df['Period']==2018)].sort_values(by=['FactValueNumeric'])
df_2018 = df_2018.reset_index()
df_2018[df_2018['Location']=='Brazil'].index + 1
# Out:
# Index([52], dtype='int64')

# %%
df_2019 = df[(df['Dim1']=='Total') & (df['Period']==2019)].sort_values(by=['FactValueNumeric'])
df_2019 = df_2019.reset_index()
df_2019[df_2019['Location']=='Brazil'].index + 1
# Out:
# Index([55], dtype='int64')
